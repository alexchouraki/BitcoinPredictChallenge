# %%
from pytrends.request import TrendReq
from bs4 import BeautifulSoup
import urllib

import numpy as np
import pandas as pd

import time
import os

pytrends = TrendReq(hl='en-US', tz=360)

# %% [markdown]
# # Petite exploration du package pytrends

# %%
bitcoin_keywords = ['blockchain', 'bitcoin', 'btc', 'cryptocurrency', 'hodl']

# %%
a = pytrends.build_payload(bitcoin_keywords, cat=0, timeframe='2017-05-01 2017-08-01', geo='', gprop='')

# %%
pytrends.interest_over_time()
# Out:
#             blockchain  bitcoin  btc  cryptocurrency  hodl  isPartial
# date
# 2017-05-01           3       23    8               2     0      False
# 2017-05-02           4       26    8               1     0      False
# 2017-05-03           4       26    8               1     0      False
# 2017-05-04           4       33   10               2     0      False
# 2017-05-05           4       31   10               2     0      False
# 2017-05-06           3       25    9               2     0      False
# 2017-05-07           3       25    8               2     0      False
# 2017-05-08           4       29   10               2     0      False
# 2017-05-09           5       37   11               2     0      False
# 2017-05-10           5       34   10               2     0      False
# 2017-05-11           5       38   11               2     0      False
# 2017-05-12           5       43   11               2     0      False
# 2017-05-13           4       44   11               2     0      False
# 2017-05-14           3       40    9               2     0      False
# 2017-05-15           4       54   10               2     0      False
# 2017-05-16           5       48   10               2     0      False
# 2017-05-17           6       41   10               2     0      False
# 2017-05-18           5       37    9               2     0      False
# 2017-05-19           5       40   10               3     0      False
# 2017-05-20           3       40   11               2     0      False
# 2017-05-21           4       41   11               3     0      False
# 2017-05-22           6       64   14               4     0      False
# 2017-05-23           6       69   14               5     0      False
# 2017-05-24           7       76   16               5     0      False
# 2017-05-25           7      100   21               6     0      False
# 2017-05-26           5       77   17               4     0      False
# 2017-05-27           4       67   16               4     0      False
# 2017-05-28           4       51   12               3     0      False
# 2017-05-29           5       50   13               3     0      False
# 2017-05-30           5       48   13               4     0      False
# ...                ...      ...  ...             ...   ...        ...
# 2017-07-03           5       34   12               4     0      False
# 2017-07-04           5       35   11               5     0      False
# 2017-07-05           5       34   11               4     0      False
# 2017-07-06           5       35   11               4     0      False
# 2017-07-07           5       33   10               4     0      False
# 2017-07-08           3       32   10               4     0      False
# 2017-07-09           4       31    9               4     0      False
# 2017-07-10           5       37   10               4     0      False
# 2017-07-11           6       43   12               6     0      False
# 2017-07-12           6       39   11               5     0      False
# 2017-07-13           5       37   11               4     0      False
# 2017-07-14           5       37   11               4     0      False
# 2017-07-15           4       42   13               4     0      False
# 2017-07-16           4       49   13               5     0      False
# 2017-07-17           5       44   12               5     0      False
# 2017-07-18           6       45   13               4     0      False
# 2017-07-19           5       41   13               4     0      False
# 2017-07-20           6       46   16               4     0      False
# 2017-07-21           5       45   14               4     0      False
# 2017-07-22           3       39   14               4     0      False
# 2017-07-23           3       39   12               4     0      False
# 2017-07-24           5       39   12               4     0      False
# 2017-07-25           5       42   13               4     0      False
# 2017-07-26           5       41   13               4     0      False
# 2017-07-27           5       40   13               4     0      False
# 2017-07-28           5       44   14               4     0      False
# 2017-07-29           4       37   11               3     0      False
# 2017-07-30           4       37   11               3     0      False
# 2017-07-31           5       46   13               3     0      False
# 2017-08-01           6       80   17               5     0      False
#
# [93 rows x 6 columns]

# %% [markdown]
# # Obtenir des chiffres pertinents sur l'année
# Par défaut, sur Google Trends, lorsque l'on fait une recherche sur un mot-clé sur une période par un an, la granularité est par semaine (et impossible d'en changer).
#
# On écrit donc quelques fonctions pour "tricher" un peu : pour un mot-clé donné, on décide donc de prendre deux périodes plus petites (sept-huit mois), quitte à rescaler la deuxième période en se servant de la période de chevauchement intermédiaire.

# %%
def google_trends_tables(keyword):
    
    # Google Trends ne permet pas d'avoir une granularité par jour sur une période d'un an.
    #
    # Pour régler le problème, je bricole un peu :
    #  - Je fais une première période qui va du 1er mai 2017 au 1er janvier 2018 (bizarrement, ça marche),
    #  - Et une deuxième période qui va du 1er octobre 2017 au 1er mai 2018.
    #
    # J'utiliserai la période de chevauchement (trois mois) pour déterminer un scale moyen, que j'applique à la
    # colonne de nouvelles valeurs.
    #
    # Les valeurs sont pas vraiment les mêmes (Google s'amuse probablement avec du sampling), mais c'est pas
    # si mal.
    
    keyword = [keyword] # La méthode build_payload demande d'avoir un objet itérable (donc liste)
    
    pytrends_before, pytrends_after = TrendReq(hl = 'en-US', tz = 0), TrendReq(hl = 'en-US', tz = 0)
    
    # Déterminer les modèles pytrends
    pytrends_before.build_payload(keyword, cat = 0, timeframe = '2017-05-01 2018-01-01', geo = '', gprop = '')
    pytrends_after.build_payload(keyword, cat=0, timeframe='2017-10-01 2018-05-01', geo='', gprop='')
    
    # On obtient les tables correspondantes
    table_before = pytrends_before.interest_over_time()
    table_after = pytrends_after.interest_over_time()
    
    return (table_before, table_after)

def scale_generator(table_before, table_after):
    
    # Fonction qui permet de scale
    
    common_table = table_before.merge(table_after, "inner", right_index = True, left_index = True)
    common_table.columns = ['before_value', 'filler1', 'after_value', 'filler2']
    common_table['scale'] = common_table.before_value / common_table.after_value
        
    return common_table.scale.mean()
    
    
def google_trends_common(keyword):
    
    # Génère une grosse table qui fusionne un peu les deux tables before et after
    
    tables = google_trends_tables(keyword)
    table_before, table_after = tables[0], tables[1]
    
    # On renomme les colonnes juste avec le mot clé
    table_before.columns = [keyword, "isPartial"]
    table_after.columns = [keyword, "isPartial"]
    
    # On applique le scale sur la deuxième table
    table_after[keyword] = table_after[keyword].apply(lambda x: int(scale_generator(table_before, table_after) * x), 1)
    
    return table_before.merge(table_after, "outer", right_index = True, left_index = True)


def trends_merge(keyword, min_length = 93):
    
    # Simplifie pour obtenir un truc un peu plus petit
    
    common_table = google_trends_common(keyword)
    
    x_values, y_values = common_table[keyword + '_x'], common_table[keyword + '_y']
    
    # Annuler les valeurs nulles
    x_values = x_values[~np.isnan(x_values)]
    y_values = y_values[~np.isnan(y_values)][min_length:]
    
    merged_values = list(x_values) + list(y_values)    
    merged_values = [value * 100 // max(merged_values) for value in merged_values]
    
    return merged_values
    
    
def google_trends_unique(keyword, min_length = 93):
    
    # Fonction finale à retenir pour l'utilisateur
    
    common_table = google_trends_common(keyword)

    common_table[keyword] = trends_merge(keyword, min_length)
    
    common_table.drop([keyword + '_x', keyword + '_y', "isPartial" + "_x", "isPartial" + "_y"], 1, inplace = True)
    
    return common_table
    

def google_trends(keywords, min_length = 93):
    
    trends = google_trends_unique(keywords[0], min_length)
    
    for keyword in keywords[1:]:
        
        trends = trends.merge(google_trends_unique(keyword), 'left', left_index = True, right_index = True)
        
    return trends

# %% [markdown]
# ## Ça donne quoi en pratique ?

# %%
trends = google_trends(['bitcoin', 'btc', 'cryptocurrency', 'hodl', 'blockchain'])
trends
# Out:
#             bitcoin   btc  cryptocurrency  hodl  blockchain
# date
# 2017-05-01      4.0  10.0             2.0   1.0        14.0
# 2017-05-02      4.0   9.0             1.0   1.0        17.0
# 2017-05-03      4.0  10.0             1.0   1.0        18.0
# 2017-05-04      5.0  12.0             2.0   1.0        18.0
# 2017-05-05      5.0  11.0             2.0   2.0        17.0
# 2017-05-06      4.0  10.0             2.0   0.0        13.0
# 2017-05-07      4.0   8.0             3.0   1.0        13.0
# 2017-05-08      4.0  11.0             3.0   2.0        17.0
# 2017-05-09      6.0  12.0             3.0   1.0        20.0
# 2017-05-10      5.0  12.0             2.0   1.0        21.0
# 2017-05-11      6.0  12.0             3.0   1.0        21.0
# 2017-05-12      7.0  12.0             2.0   1.0        21.0
# 2017-05-13      7.0  12.0             2.0   1.0        14.0
# 2017-05-14      6.0  11.0             2.0   1.0        15.0
# 2017-05-15      8.0  11.0             2.0   0.0        18.0
# 2017-05-16      8.0  11.0             3.0   1.0        22.0
# 2017-05-17      6.0  11.0             4.0   1.0        23.0
# 2017-05-18      6.0  10.0             3.0   1.0        20.0
# 2017-05-19      6.0  12.0             4.0   1.0        21.0
# 2017-05-20      6.0  12.0             3.0   3.0        15.0
# 2017-05-21      7.0  12.0             4.0   1.0        15.0
# 2017-05-22     10.0  16.0             6.0   1.0        26.0
# 2017-05-23     11.0  16.0             7.0   1.0        26.0
# 2017-05-24     12.0  18.0             8.0   3.0        29.0
# 2017-05-25     16.0  24.0            10.0   5.0        31.0
# 2017-05-26     12.0  19.0             6.0   3.0        23.0
# 2017-05-27     11.0  19.0             6.0   3.0        17.0
# 2017-05-28      8.0  14.0             5.0   1.0        18.0
# 2017-05-29      8.0  14.0             5.0   1.0        20.0
# 2017-05-30      8.0  14.0             6.0   4.0        24.0
# ...             ...   ...             ...   ...         ...
# 2018-04-02     10.0  14.0            13.0   5.0        34.0
# 2018-04-03      9.0  15.0            13.0   6.0        38.0
# 2018-04-04      9.0  14.0            12.0   6.0        40.0
# 2018-04-05      9.0  14.0            15.0   4.0        38.0
# 2018-04-06     10.0  14.0            14.0  11.0        36.0
# 2018-04-07      8.0  12.0            10.0   7.0        24.0
# 2018-04-08      7.0  12.0            10.0   5.0        25.0
# 2018-04-09      9.0  13.0            12.0   6.0        37.0
# 2018-04-10      8.0  13.0            11.0   6.0        41.0
# 2018-04-11      8.0  12.0            10.0   5.0        42.0
# 2018-04-12     10.0  16.0            13.0   6.0        39.0
# 2018-04-13     10.0  17.0            15.0   6.0        36.0
# 2018-04-14      7.0  13.0            10.0   3.0        23.0
# 2018-04-15      7.0  13.0            10.0   3.0        25.0
# 2018-04-16      8.0  14.0            11.0   3.0        38.0
# 2018-04-17      8.0  13.0            13.0   5.0        42.0
# 2018-04-18      8.0  12.0            13.0   4.0        41.0
# 2018-04-19      8.0  13.0            13.0   5.0        42.0
# 2018-04-20      8.0  15.0            14.0   5.0        39.0
# 2018-04-21      7.0  14.0            12.0   4.0        26.0
# 2018-04-22      7.0  13.0            11.0   4.0        28.0
# 2018-04-23      8.0  14.0            12.0   3.0        42.0
# 2018-04-24     10.0  17.0            15.0   6.0        41.0
# 2018-04-25      9.0  16.0            14.0   4.0        41.0
# 2018-04-26      7.0  14.0            12.0   3.0        39.0
# 2018-04-27      7.0  14.0            11.0   3.0        38.0
# 2018-04-28      6.0  14.0            10.0   3.0        27.0
# 2018-04-29      6.0  13.0            11.0   3.0        25.0
# 2018-04-30      7.0  14.0            12.0   4.0        37.0
# 2018-05-01      7.0  13.0            12.0   3.0        36.0
#
# [366 rows x 5 columns]

# %% [markdown]
# On extrait ensuite les données dans un fichier .csv, qui sera exploité sur le notebook R (plus facile à utiliser pour les modèles de prédiction).

# %%
trends.to_csv('./data/trends.csv')

# %% [markdown]
# # Tentative de scraping à partir de résultats Google

# %%
import feedparser

d = feedparser.parse("http://feeds.reuters.com/reuters/technologyNews")

# %%
import requests
r = requests.get("https://www.google.com/search?q=bitcoin&tbas=0&tbs=cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&tbm=nws&ei=GuygW9O9Gc7LsAHi0Y3gBQ&sa=N&biw=709&bih=821&dpr=1&start=0",
                 headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0'})

soup = BeautifulSoup(r.text, "html.parser")

# %%
def google_scraper(document_url, min_ind = 0, max_ind = np.Inf, step = 1, sleep = 1, header = True, **kwargs):
        
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3112.113 Safari/537.36'}
    # Header to show that we are not a bot
    # Note that for some reason, the function works much better if we pretend we are using Chrome:
    #  - The time filter (from May 1st 2017 to May 1st 2018) works as intended, which is not the case with Firefox,
    #  - The date in the snippets can be recognised normally, thanks to its HTML tag
    
    results = pd.DataFrame(columns = kwargs)
    
    ind = min_ind - step # The number of the pages that we iterate through
    attempt = 0
    
    if document_url[-1] == '1':
        document_url = document_url[:-1] # In order to have the proper number of pages!
    
    print('Document: ', document_url)

    while True and ind < max_ind:
        ind += step
        print('Page', ind, " –  URL: ", document_url + str(ind)) # Proves the algorithm is still working
        result = pd.DataFrame(columns = kwargs)
        time.sleep(sleep) # May be needed against anti-bot measures?
        
        try:
            if header == True:
                req = requests.get(document_url + str(ind), headers = headers)
            else: # Sometimes (like with BestBuy), it does not even work if there is a header ...
                req = requests.get(document_url + str(ind))
                
            soup = BeautifulSoup(req.text, "html.parser")
    
            for key, value in kwargs.items():
                result[str(key)] = soup.findAll(value[0], value[1])
            
            result['page'] = (ind // step) + (1 - min_ind)
            results = results.append(result, ignore_index = True)
            
            if len(result) == 0 and attempt >= 3: # If the result is empty, there are no more comments to get -> we break the loop
                return(results)
            
            elif len(result) == 0:
                attempt += 1
                ind -= 10
                print ('Attempt no.' + str(attempt))
                
            else:
                attempt = 0
        
        except KeyboardInterrupt: # If we want to stop the code, well, we still retain our data
            print('Keyboard Interrupt')
            return(results)
        
        #except: # Prevents the code from stopping abruptly (sometimes the website will return an error for no reason)
        #    print('Some error:', ind)
        #    continue
            
    else:
        return(results)

# %%
def data_scraper(html_doc, html_type, html_class):
    
    try:
        result = html_doc.findAll(html_type, html_class)[0].text
        
    except IndexError:
        result = np.NaN
        
    return result

def data_interpretator(result, col_name, **kwargs):
    
    for key, value in kwargs.items():
        
        result[str(key)] = result[col_name].apply(lambda x: data_scraper(x, value[0], value[1]))
        
    return result

# %%
bbc_results = google_scraper("https://www.google.com/search?q=bitcoin+site:bbc.com&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start=",
              step = 10, max_ind = 20, snippet = ("div", "g"))
# Out:
# Document:  https://www.google.com/search?q=bitcoin+site:bbc.com&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start=
# Page 0  –  URL:  https://www.google.com/search?q=bitcoin+site:bbc.com&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start=0
# Page 10  –  URL:  https://www.google.com/search?q=bitcoin+site:bbc.com&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start=10
# Page 20  –  URL:  https://www.google.com/search?q=bitcoin+site:bbc.com&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start=20

# %%
bbc_results
# Out:
#     page                                            snippet
# 0    0.0  <div class="g"><!--m--><div data-hveid="CAAQAA...
# 1    0.0  <div class="g"><!--m--><div data-hveid="CAkQAA...
# 2    0.0  <div class="g"><!--m--><div data-hveid="CAgQAA...
# 3    0.0  <div class="g"><!--m--><div data-hveid="CAcQAA...
# 4    0.0  <div class="g"><!--m--><div data-hveid="CAYQAA...
# 5    0.0  <div class="g"><!--m--><div data-hveid="CAUQAA...
# 6    0.0  <div class="g"><!--m--><div data-hveid="CAMQAA...
# 7    0.0  <div class="g"><!--m--><div data-hveid="CAQQAA...
# 8    0.0  <div class="g"><!--m--><div data-hveid="CAIQAA...
# 9    0.0  <div class="g"><!--m--><div data-hveid="CAEQAA...
# 10   1.0  <div class="g"><!--m--><div data-hveid="CAEQAA...
# 11   1.0  <div class="g"><!--m--><div data-hveid="CAgQAA...
# 12   1.0  <div class="g"><!--m--><div data-hveid="CAcQAA...
# 13   1.0  <div class="g"><!--m--><div data-hveid="CAkQAA...
# 14   1.0  <div class="g"><!--m--><div data-hveid="CAYQAA...
# 15   1.0  <div class="g"><!--m--><div data-hveid="CAQQAA...
# 16   1.0  <div class="g"><!--m--><div data-hveid="CAUQAA...
# 17   1.0  <div class="g"><!--m--><div data-hveid="CAMQAA...
# 18   1.0  <div class="g"><!--m--><div data-hveid="CAIQAA...
# 19   1.0  <div class="g"><!--m--><div data-hveid="CAAQAA...
# 20   2.0  <div class="g"><!--m--><div data-hveid="CAAQAA...
# 21   2.0  <div class="g"><!--m--><div data-hveid="CAgQAA...
# 22   2.0  <div class="g"><!--m--><div data-hveid="CAkQAA...
# 23   2.0  <div class="g"><!--m--><div data-hveid="CAcQAA...
# 24   2.0  <div class="g"><!--m--><div data-hveid="CAYQAA...
# 25   2.0  <div class="g"><!--m--><div data-hveid="CAUQAA...
# 26   2.0  <div class="g"><!--m--><div data-hveid="CAQQAA...
# 27   2.0  <div class="g"><!--m--><div data-hveid="CAEQAA...
# 28   2.0  <div class="g"><!--m--><div data-hveid="CAIQAA...
# 29   2.0  <div class="g"><!--m--><div data-hveid="CAMQAA...
# 30   3.0  <div class="g"><!--m--><div data-hveid="CAAQAA...
# 31   3.0  <div class="g"><!--m--><div data-hveid="CAgQAA...
# 32   3.0  <div class="g"><!--m--><div data-hveid="CAkQAA...
# 33   3.0  <div class="g"><!--m--><div data-hveid="CAcQAA...
# 34   3.0  <div class="g"><!--m--><div data-hveid="CAYQAA...
# 35   3.0  <div class="g"><!--m--><div data-hveid="CAUQAA...
# 36   3.0  <div class="g"><!--m--><div data-hveid="CAQQAA...
# 37   3.0  <div class="g"><!--m--><div data-hveid="CAMQAA...
# 38   3.0  <div class="g"><!--m--><div data-hveid="CAEQAA...
# 39   3.0  <div class="g"><!--m--><div data-hveid="CAIQAA...

# %%
bbc_results_bis = bbc_results

# %%
data_interpretator(bbc_results, "snippet",
                   title = ('h3', 'r'),
                   abstract = ('span', 'st'),
                   date = ('span', 'f'))

bbc_results['source'] = 'BBC.com'

# %%
bbc_results
# Out:
#                                                snippet  \
# 0    <div class="g"><!--m--><div data-hveid="CAIQAA...
# 1    <div class="g"><!--m--><div data-hveid="CAkQAA...
# 2    <div class="g"><!--m--><div data-hveid="CAcQAA...
# 3    <div class="g"><!--m--><div data-hveid="CAgQAA...
# 4    <div class="g"><!--m--><div data-hveid="CAYQAA...
# 5    <div class="g"><!--m--><div data-hveid="CAUQAA...
# 6    <div class="g"><!--m--><div data-hveid="CAQQAA...
# 7    <div class="g"><!--m--><div data-hveid="CAMQAA...
# 8    <div class="g"><!--m--><div data-hveid="CAEQAA...
# 9    <div class="g"><!--m--><div data-hveid="CAAQAA...
# 10   <div class="g"><!--m--><div data-hveid="CAMQAA...
# 11   <div class="g"><!--m--><div data-hveid="CAkQAA...
# 12   <div class="g"><!--m--><div data-hveid="CAgQAA...
# 13   <div class="g"><!--m--><div data-hveid="CAcQAA...
# 14   <div class="g"><!--m--><div data-hveid="CAUQAA...
# 15   <div class="g"><!--m--><div data-hveid="CAEQAA...
# 16   <div class="g"><!--m--><div data-hveid="CAQQAA...
# 17   <div class="g"><!--m--><div data-hveid="CAYQAA...
# 18   <div class="g"><!--m--><div data-hveid="CAAQAA...
# 19   <div class="g"><!--m--><div data-hveid="CAIQAA...
# 20   <div class="g"><!--m--><div data-hveid="CAAQAA...
# 21   <div class="g"><!--m--><div data-hveid="CAkQAA...
# 22   <div class="g"><!--m--><div data-hveid="CAgQAA...
# 23   <div class="g"><!--m--><div data-hveid="CAcQAA...
# 24   <div class="g"><!--m--><div data-hveid="CAYQAA...
# 25   <div class="g"><!--m--><div data-hveid="CAUQAA...
# 26   <div class="g"><!--m--><div data-hveid="CAQQAA...
# 27   <div class="g"><!--m--><div data-hveid="CAIQAA...
# 28   <div class="g"><!--m--><div data-hveid="CAMQAA...
# 29   <div class="g"><!--m--><div data-hveid="CAEQAA...
# ..                                                 ...
# 162  <div class="g"><!--m--><div data-hveid="CAgQAA...
# 163  <div class="g"><!--m--><div data-hveid="CAcQAA...
# 164  <div class="g"><!--m--><div data-hveid="CAYQAA...
# 165  <div class="g"><!--m--><div data-hveid="CAUQAA...
# 166  <div class="g"><!--m--><div data-hveid="CAQQAA...
# 167  <div class="g"><!--m--><div data-hveid="CAMQAA...
# 168  <div class="g"><!--m--><div data-hveid="CAIQAA...
# 169  <div class="g"><!--m--><div data-hveid="CAAQAA...
# 170  <div class="g"><!--m--><div data-hveid="CAEQAA...
# 171  <div class="g"><!--m--><div data-hveid="CAkQAA...
# 172  <div class="g"><!--m--><div data-hveid="CAgQAA...
# 173  <div class="g"><!--m--><div data-hveid="CAcQAA...
# 174  <div class="g"><!--m--><div data-hveid="CAUQAA...
# 175  <div class="g"><!--m--><div data-hveid="CAYQAA...
# 176  <div class="g"><!--m--><div data-hveid="CAMQAA...
# 177  <div class="g"><!--m--><div data-hveid="CAQQAA...
# 178  <div class="g"><!--m--><div data-hveid="CAIQAA...
# 179  <div class="g"><!--m--><div data-hveid="CAAQAA...
# 180  <div class="g"><!--m--><div data-hveid="CAMQAA...
# 181  <div class="g"><!--m--><div data-hveid="CAgQAA...
# 182  <div class="g"><!--m--><div data-hveid="CAkQAA...
# 183  <div class="g"><!--m--><div data-hveid="CAcQAA...
# 184  <div class="g"><!--m--><div data-hveid="CAUQAA...
# 185  <div class="g"><!--m--><div data-hveid="CAYQAA...
# 186  <div class="g"><!--m--><div data-hveid="CAQQAA...
# 187  <div class="g"><!--m--><div data-hveid="CAIQAA...
# 188  <div class="g"><!--m--><div data-hveid="CAAQAA...
# 189  <div class="g"><!--m--><div data-hveid="CAEQAA...
# 190  <div class="g"><!--m--><div data-hveid="CAAQAA...
# 191  <div class="g"><!--m--><div data-hveid="CAEQAA...
#
#                                               abstract              date  \
# 0    7 sept. 2017 - Bitcoin is notorious for its vo...   7 sept. 2017 -
# 1    27 déc. 2017 - Bitcoin. Lots of people are tal...   27 déc. 2017 -
# 2    7 mars 2018 - BBC investigation discovers shad...    7 mars 2018 -
# 3    27 nov. 2017 - First, full disclosure - I am a...   27 nov. 2017 -
# 4    12 déc. 2017 - The internet has recently been ...   12 déc. 2017 -
# 5    11 déc. 2017 - The value of digital currency B...   11 déc. 2017 -
# 6    5 févr. 2018 - The value of Bitcoin has fallen...   5 févr. 2018 -
# 7    8 déc. 2017 - In its early days, Bitcoin might...    8 déc. 2017 -
# 8    25 janv. 2018 - 50 Cent has discovered that he...  25 janv. 2018 -
# 9    9 févr. 2018 - Crypto-currencies like Bitcoin ...   9 févr. 2018 -
# 10   5 mars 2018 - Bitcoin entrepreneurs want to re...    5 mars 2018 -
# 11   8 janv. 2018 - African millennials explain to ...   8 janv. 2018 -
# 12   21 déc. 2017 - On Wednesday, cryptocurrency Bi...   21 déc. 2017 -
# 13   17 janv. 2018 - Bitcoin, for example, has lost...  17 janv. 2018 -
# 14   22 déc. 2017 - Bitcoin plunged on Friday, exte...   22 déc. 2017 -
# 15   8 déc. 2017 - "Highly professional" hackers ma...    8 déc. 2017 -
# 16   8 déc. 2017 - Bitcoin continued its rollercoas...    8 déc. 2017 -
# 17   5 févr. 2018 - A secret code hidden in a paint...   5 févr. 2018 -
# 18   1 déc. 2017 - The Bitcoin boom has prompted a ...    1 déc. 2017 -
# 19   27 nov. 2017 - Virtual currency Bitcoin hit a ...   27 nov. 2017 -
# 20   9 janv. 2018 - The photo firm Kodak is to crea...   9 janv. 2018 -
# 21   29 nov. 2017 - The value of one bitcoin has go...   29 nov. 2017 -
# 22   20 déc. 2017 - Coinbase is investigating wheth...   20 déc. 2017 -
# 23   18 déc. 2017 - Bitcoin has moved another step ...   18 déc. 2017 -
# 24   19 sept. 2017 - All Bitcoin exchanges in Beiin...  19 sept. 2017 -
# 25   30 nov. 2017 - The price of digital currency B...   30 nov. 2017 -
# 26   7 août 2017 - Bitcoin's value has jumped to a ...    7 août 2017 -
# 27   8 déc. 2017 - The digital currency Bitcoin is ...    8 déc. 2017 -
# 28   24 mai 2017 - The price of Bitcoin, a digital ...    24 mai 2017 -
# 29   1 déc. 2017 - This rollercoaster ride, and res...    1 déc. 2017 -
# ..                                                 ...               ...
# 162  27 juil. 2017 - Payments typically have to be ...  27 juil. 2017 -
# 163  24 oct. 2017 - Bad Rabbit encrypts the content...   24 oct. 2017 -
# 164  31 oct. 2017 - The website was informed that s...   31 oct. 2017 -
# 165  8 déc. 2017 - Then a journalist's phone rang a...    8 déc. 2017 -
# 166  25 sept. 2017 - Their operation was said to be...  25 sept. 2017 -
# 167  28 juil. 2017 - North Korea is also reported t...  28 juil. 2017 -
# 168  6 oct. 2017 - The boom in the value of Bitcoin...    6 oct. 2017 -
# 169  7 févr. 2018 - Proceeds were said to have been...   7 févr. 2018 -
# 170  28 nov. 2017 - He also dismissed the idea that...   28 nov. 2017 -
# 171  7 nov. 2017 - Could the system that underpins ...    7 nov. 2017 -
# 172  21 févr. 2018 - Crypto-jacking is becoming mor...  21 févr. 2018 -
# 173  20 déc. 2017 - Kurt Lai Lan traded in MDMA on ...   20 déc. 2017 -
# 174  13 mai 2017 - ... asanga adashobora kwinjira, ...    13 mai 2017 -
# 175  28 déc. 2017 - Lacagta aan muuqan ee Bitcoin a...   28 déc. 2017 -
# 176  8 déc. 2017 - Bitcoin - which many see as a sp...    8 déc. 2017 -
# 177  16 mai 2017 - Image copyright AFP/Getty Image ...    16 mai 2017 -
# 178  5 sept. 2017 - Follow Technology of Business e...   5 sept. 2017 -
# 179  9 nov. 2017 - Criminal's Bitcoin seized in pol...    9 nov. 2017 -
# 180  20 oct. 2017 - Image copyright EPA Image capti...   20 oct. 2017 -
# 181  13 mai 2017 - There is no indication of who is...    13 mai 2017 -
# 182  13 mai 2017 - NHS staff shared screenshots of ...    13 mai 2017 -
# 183  20 janv. 2018 - The first episode of Britannia...  20 janv. 2018 -
# 184  16 mai 2017 - One cyber-security analyst also ...    16 mai 2017 -
# 185  9 nov. 2017 - Ethereum is a crypto-currency si...    9 nov. 2017 -
# 186  29 mars 2018 - The script is full of current r...   29 mars 2018 -
# 187  19 déc. 2017 - Image copyright EPA Image capti...   19 déc. 2017 -
# 188  28 déc. 2017 - The Scotland-born entrepreneur ...   28 déc. 2017 -
# 189  16 mai 2017 - He added that the hackers had de...    16 mai 2017 -
# 190  3 janv. 2018 - A team of Google researchers ha...   3 janv. 2018 -
# 191  10 avr. 2018 - No more peashooter as the US to...   10 avr. 2018 -
#
#                                                  title   source
# 0    BBC - Capital - What you need to know about th...  BBC.com
# 1    Bitcoin: Would you want to get paid in cryptoc...  BBC.com
# 2    UK company linked to laundered Bitcoin billion...  BBC.com
# 3    Bitcoin - risky bubble or the future? - BBC Ne...  BBC.com
# 4    Bitcoin: Does it really use more electricity t...  BBC.com
# 5                          What is Bitcoin? - BBC News  BBC.com
# 6      Bitcoin falls below $6,000 - BBC News - BBC.com  BBC.com
# 7       Bitcoin: 'I'm part of a crazy wave' - BBC News  BBC.com
# 8    50 Cent forgot he had a stash of Bitcoin now w...  BBC.com
# 9    Russian nuclear scientists arrested for 'Bitco...  BBC.com
# 10   BBC - Capital - Should Bitcoin be used to help...  BBC.com
# 11   Why African millennials can't get enough of Bi...  BBC.com
# 12   Bitcoin: Should we care about its price? - BBC...  BBC.com
# 13   Bitcoin: South Korea sways cryptocurrency pric...  BBC.com
# 14   Bitcoin slump sees trades suspended on certain...  BBC.com
# 15   Millions 'stolen' in NiceHash Bitcoin heist - ...  BBC.com
# 16   Bitcoin's rollercoaster ride after hitting $17...  BBC.com
# 17   Bitcoin puzzle worth $50,000 solved after near...  BBC.com
# 18   Cyber-thieves seek to cash in on Bitcoin boom ...  BBC.com
# 19   Bitcoin currency hits new record high - BBC Ne...  BBC.com
# 20   CES 2018: Kodak soars on KodakCoin and Bitcoin...  BBC.com
# 21   Bitcoin crosses $10,000 milestone - BBC News -...  BBC.com
# 22   Bitcoin Cash deals frozen as insider trading i...  BBC.com
# 23   Bitcoin trading starts on the huge CME exchang...  BBC.com
# 24   China orders Bitcoin exchanges in capital city...  BBC.com
# 25   Bitcoin slides amid rollercoaster ride - BBC N...  BBC.com
# 26   Bitcoin soars to record high value - BBC News ...  BBC.com
# 27   India warns on Bitcoin as investors rush in - ...  BBC.com
# 28   It's not just Bitcoin anymore... - BBC News - ...  BBC.com
# 29            BBC - Capital - The wild week of Bitcoin  BBC.com
# ..                                                 ...      ...
# 162  Ransomware 'here to stay', warns Google study ...  BBC.com
# 163  'Bad Rabbit' ransomware strikes Ukraine and Ru...  BBC.com
# 164  Malaysian data breach sees 46 million phone nu...  BBC.com
# 165  Ten Premier League news conferences plus build...  BBC.com
# 166  Dark web drug supermarket duo from Huddersfiel...  BBC.com
# 167  North Korea hackers 'want cash not secrets' - ...  BBC.com
# 168  Tech Tent: Google hardware, computer mining, s...  BBC.com
# 169  Dozens charged for Infraud cyber-crime site - ...  BBC.com
# 170  Fed nominee Jerome Powell shares views with Co...  BBC.com
# 171  IBM pitches blockchain for cannabis sale - BBC...  BBC.com
# 172  Tesla investigates claims of crypto-currency h...  BBC.com
# 173  Portsmouth dark net drug dealer jailed for 16 ...  BBC.com
# 174  Umugera wateye muri za mudasobwa mw'isi yose -...  BBC.com
# 175  2017: Sanad ay soo baxeen tirooyin lama filaan...  BBC.com
# 176  Business Live: Pound gives up gains - BBC News...  BBC.com
# 177   WannaCry and the malware hall of fame - BBC News  BBC.com
# 178  Is this the next financial scandal waiting to ...  BBC.com
# 179                        Money laundering - BBC News  BBC.com
# 180                                                NaN  BBC.com
# 181                                                NaN  BBC.com
# 182                                                NaN  BBC.com
# 183                                                NaN  BBC.com
# 184                                                NaN  BBC.com
# 185                                                NaN  BBC.com
# 186                                                NaN  BBC.com
# 187                                                NaN  BBC.com
# 188                                                NaN  BBC.com
# 189                                                NaN  BBC.com
# 190  Psychedelic toasters fool image recognition te...  BBC.com
# 191  US gets out the sanctions howitzer - BBC News ...  BBC.com
#
# [192 rows x 5 columns]

# %% [markdown]
# # Etablissement d'un corpus de sites
#
# Ce corpus est composé de trois types de sites Internet, qui offrent chacun une perspective legèrement différente :
#
# - Les sites de journaux orientés économique (type Financial Times, Wall Street Journal), qui s'intéressent au sujet, mais peut-être de manière un peu conservatrice,
#
# - Les sites de journaux généralistes (The Guardian), qui suivent l'affaire d'un peu plus loin, et qui ont de bonnes chances *a priori* de suivre la hype lorsque le marché monte, et d'en parler beaucoup moins après une chute,
#
# - Les sites spécialisés (Coindesk).

# %%
financial_newspapers = ['ft.com', 'bbc.com', 'cnn.com', 'cnbc.com', 'economist.com', 'forbes.com', 'wsj.com',
                        'bloomberg.com', 'investopedia.com', 'fortune.com', 'foxbusiness.com', 'born2invest.com',
                        'economictimes.indiatimes.com', 'business-standard.com', 'reuters.com']

general_newspapers = ['theguardian.com', 'nytimes.com', 'washingtonpost.com', 'chicagotribune.com', 'abcnews.go.com',
                      'cbsnews.com', 'nbcnews.com', 'thetimes.co.uk', 'independent.co.uk', 'time.com']

crypto_websites = ['coindesk.com', 'coinjournal.net', 'coininsider.com', 'cointelegraph.com', 'bitcoinmagazine.com',
                   'cryptonews.com']

# %%
def table_generator(website_list, max_ind = 400, sleep = 1):
    
    final_output = pd.DataFrame(columns = ['snippet', 'page', 'date', 'title', 'abstract'])
    
    for newspaper in website_list:
        
        google_url = "https://www.google.com/search?q=bitcoin+site:" + newspaper + "&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start="
        
        newspaper_results = google_scraper(google_url, step = 10, max_ind = max_ind, sleep = sleep, snippet = ('div', 'g'))
        
        data_interpretator(newspaper_results, "snippet",
                   title = ('h3', 'r'),
                   abstract = ('span', 'st'),
                   date = ('span', 'f'))
        
        newspaper_results['source'] = newspaper
        
        final_output = final_output.append(newspaper_results, ignore_index = True)
        
    return final_output

# %%
financial_table = table_generator(financial_newspapers, max_ind = 400, sleep = 5)
# Out:
# Document:  https://www.google.com/search?q=bitcoin+site:ft.com&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start=
# Page 0  –  URL:  https://www.google.com/search?q=bitcoin+site:ft.com&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start=0
# Page 10  –  URL:  https://www.google.com/search?q=bitcoin+site:ft.com&lr=lang_en&rlz=1C5CHFA_enFR566FR566&tbs=lr:lang_1en,cdr:1,cd_min:5/1/2017,cd_max:5/1/2018&ei=3lGhW73pC8r3qwGV6Kn4BQ&sa=N&biw=709&bih=821&start=10

# %%
financial_table.snippet[30].findAll('h3', 'r')
# Out:
# []
